# %%
# Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Open the Data set

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
# Remove the categorical data(i.e str-state)

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
# splite the input & output columns

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independant=dataset[['age','bmi','children','sex_male','smoker_yes']]

# %%
independant
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependant= dataset[['charges']]

# %%
dependant
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
#split the Train & Test dataset

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(independant,dependant,test_size=0.30,random_state=0)

# %%
X_train
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 1163   18  28.215         0         0           0
# 196    39  32.800         0         0           0
# 438    52  46.750         5         0           0
# 183    44  26.410         0         0           0
# 1298   33  27.455         2         1           0
# ...   ...     ...       ...       ...         ...
# 763    27  26.030         0         1           0
# 835    42  35.970         2         1           0
# 1216   40  25.080         0         1           0
# 559    19  35.530         0         1           0
# 684    33  18.500         1         0           0
#
# [936 rows x 5 columns]

# %%
# Train data-Model creation

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid= { 'criterion':['squared_error','absolute-error','mae','friedman_mse','poisson'],'max_features':['auto','sqrt','log2'],'splitter':['best','ramdom']}

grid= GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)

# Fitting the Model for grid seach                 
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 120 fits failed out of a total of 150.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 29 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'splitter' parameter of DecisionTreeRegressor must be a str among {'best', 'random'}. Got 'ramdom' instead.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'splitter' parameter of DecisionTreeRegressor must be a str among {'random', 'best'}. Got 'ramdom' instead.
#
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'squared_error', 'friedman_mse', 'poisson', 'absolute_error'}. Got 'absolute-error' instead.
#
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'friedman_mse', 'squared_error', 'absolute_error', 'poisson'}. Got 'absolute-error' instead.
#
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'absolute_error', 'squared_error', 'poisson', 'friedman_mse'}. Got 'absolute-error' instead.
#
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'friedman_mse', 'squared_error', 'absolute_error', 'poisson'}. Got 'mae' instead.
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'absolute_error', 'squared_error', 'poisson', 'friedman_mse'}. Got 'mae' instead.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'squared_error', 'friedman_mse', 'poisson', 'absolute_error'}. Got 'mae' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.63121385        nan 0.61382663        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.63385863        nan 0.57174348        nan
#         nan        nan 0.61870081        nan 0.64794014        nan]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute-error', 'mae',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'ramdom']},
#              verbose=3)

# %%
# print best parameter after turning
# print(grid_best_params_)

# %%
re=grid.cv_results_
print("The r_score_value for best parameters:",format(grid.best_params_))
# Out:
# The r_score_value for best parameters: {'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'best'}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002798      0.001165         0.000000        0.000000
# 1        0.004397      0.001019         0.000000        0.000000
# 2        0.140516      0.100099         0.068559        0.047438
# 3        0.002796      0.000748         0.000000        0.000000
# 4        0.014190      0.003123         0.010319        0.003556
# 5        0.004197      0.000748         0.000000        0.000000
# 6        0.003799      0.001469         0.000000        0.000000
# 7        0.004198      0.000978         0.000000        0.000000
# 8        0.002999      0.000633         0.000000        0.000000
# 9        0.003398      0.002330         0.000000        0.000000
# 10       0.003998      0.001412         0.000000        0.000000
# 11       0.003004      0.000315         0.000000        0.000000
# 12       0.003300      0.001172         0.000000        0.000000
# 13       0.003398      0.000801         0.000000        0.000000
# 14       0.003701      0.000985         0.000000        0.000000
# 15       0.003804      0.000511         0.000000        0.000000
# 16       0.003508      0.000838         0.000000        0.000000
# 17       0.003197      0.000399         0.000000        0.000000
# 18       0.003807      0.000404         0.000000        0.000000
# 19       0.002797      0.000750         0.000000        0.000000
# 20       0.015213      0.002301         0.007796        0.001325
# 21       0.003407      0.000961         0.000000        0.000000
# 22       0.014012      0.001308         0.007801        0.001127
# 23       0.002799      0.000400         0.000000        0.000000
# 24       0.003407      0.000979         0.000000        0.000000
# 25       0.002701      0.000398         0.000000        0.000000
# 26       0.014710      0.000765         0.008298        0.000868
# 27       0.003797      0.001166         0.000000        0.000000
# 28       0.014608      0.004343         0.007061        0.001253
# 29       0.002798      0.000748         0.000000        0.000000
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               auto           best
# 1    squared_error               auto         ramdom
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         ramdom
# 4    squared_error               log2           best
# 5    squared_error               log2         ramdom
# 6   absolute-error               auto           best
# 7   absolute-error               auto         ramdom
# 8   absolute-error               sqrt           best
# 9   absolute-error               sqrt         ramdom
# 10  absolute-error               log2           best
# 11  absolute-error               log2         ramdom
# 12             mae               auto           best
# 13             mae               auto         ramdom
# 14             mae               sqrt           best
# 15             mae               sqrt         ramdom
# 16             mae               log2           best
# 17             mae               log2         ramdom
# 18    friedman_mse               auto           best
# 19    friedman_mse               auto         ramdom
# 20    friedman_mse               sqrt           best
# 21    friedman_mse               sqrt         ramdom
# 22    friedman_mse               log2           best
# 23    friedman_mse               log2         ramdom
# 24         poisson               auto           best
# 25         poisson               auto         ramdom
# 26         poisson               sqrt           best
# 27         poisson               sqrt         ramdom
# 28         poisson               log2           best
# 29         poisson               log2         ramdom
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.771903
# 3   {'criterion': 'squared_error', 'max_features':...                NaN
# 4   {'criterion': 'squared_error', 'max_features':...           0.673903
# 5   {'criterion': 'squared_error', 'max_features':...                NaN
# 6   {'criterion': 'absolute-error', 'max_features'...                NaN
# 7   {'criterion': 'absolute-error', 'max_features'...                NaN
# 8   {'criterion': 'absolute-error', 'max_features'...                NaN
# 9   {'criterion': 'absolute-error', 'max_features'...                NaN
# 10  {'criterion': 'absolute-error', 'max_features'...                NaN
# 11  {'criterion': 'absolute-error', 'max_features'...                NaN
# 12  {'criterion': 'mae', 'max_features': 'auto', '...                NaN
# 13  {'criterion': 'mae', 'max_features': 'auto', '...                NaN
# 14  {'criterion': 'mae', 'max_features': 'sqrt', '...                NaN
# 15  {'criterion': 'mae', 'max_features': 'sqrt', '...                NaN
# 16  {'criterion': 'mae', 'max_features': 'log2', '...                NaN
# 17  {'criterion': 'mae', 'max_features': 'log2', '...                NaN
# 18  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 19  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 20  {'criterion': 'friedman_mse', 'max_features': ...           0.699643
# 21  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 22  {'criterion': 'friedman_mse', 'max_features': ...           0.646339
# 23  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 24  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 25  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 26  {'criterion': 'poisson', 'max_features': 'sqrt...           0.700515
# 27  {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 28  {'criterion': 'poisson', 'max_features': 'log2...           0.743884
# 29  {'criterion': 'poisson', 'max_features': 'log2...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.613310           0.617165           0.658690
# 3                 NaN                NaN                NaN
# 4            0.568578           0.717265           0.467559
# 5                 NaN                NaN                NaN
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8                 NaN                NaN                NaN
# 9                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14                NaN                NaN                NaN
# 15                NaN                NaN                NaN
# 16                NaN                NaN                NaN
# 17                NaN                NaN                NaN
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.607821           0.632774           0.570576
# 21                NaN                NaN                NaN
# 22           0.605662           0.638309           0.321018
# 23                NaN                NaN                NaN
# 24                NaN                NaN                NaN
# 25                NaN                NaN                NaN
# 26           0.564017           0.609525           0.611013
# 27                NaN                NaN                NaN
# 28           0.608469           0.702027           0.570805
# 29                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN                7
# 1                 NaN              NaN             NaN                7
# 2            0.495001         0.631214        0.089017                3
# 3                 NaN              NaN             NaN                7
# 4            0.641827         0.613827        0.087789                5
# 5                 NaN              NaN             NaN                7
# 6                 NaN              NaN             NaN                7
# 7                 NaN              NaN             NaN                7
# 8                 NaN              NaN             NaN                7
# 9                 NaN              NaN             NaN                7
# 10                NaN              NaN             NaN                7
# 11                NaN              NaN             NaN                7
# 12                NaN              NaN             NaN                7
# 13                NaN              NaN             NaN                7
# 14                NaN              NaN             NaN                7
# 15                NaN              NaN             NaN                7
# 16                NaN              NaN             NaN                7
# 17                NaN              NaN             NaN                7
# 18                NaN              NaN             NaN                7
# 19                NaN              NaN             NaN                7
# 20           0.658479         0.633859        0.043858                2
# 21                NaN              NaN             NaN                7
# 22           0.647390         0.571743        0.126279                6
# 23                NaN              NaN             NaN                7
# 24                NaN              NaN             NaN                7
# 25                NaN              NaN             NaN                7
# 26           0.608435         0.618701        0.044570                4
# 27                NaN              NaN             NaN                7
# 28           0.614516         0.647940        0.064429                1
# 29                NaN              NaN             NaN                7

# %%
age_input=float(input("Age:"))
bmi_input=float(input("bmi:"))
children_input=float(input("Children"))
sex_male_input=int(input("Sex_Male 0 or 1 :"))
smoker_input= int(input("Smoker Yes 0 to 1 :"))
# Out:
# Age: 25
# bmi: 38
# Children 2
# Sex_Male 0 or 1 : 1
# Smoker Yes 0 to 1 : 0

# %%
Future_prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_input]])
print("Future_Prediction-",format(Future_prediction))
# Out:
# Future_Prediction- [3877.30425]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
