# %%
# Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# open a Dataset

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#Remove the categorical data (i.e str change into numbers)

# %%
dataset= pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
# Split the Input  Output dataes

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independant=dataset[['age','bmi', 'children','sex_male','smoker_yes']]

# %%
independant
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependant= dataset[['charges']]

# %%
dependant
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
#split the Train & Test data

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test= train_test_split(independant,dependant,test_size=0.30, random_state=0)

# %%
X_train
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 1163   18  28.215         0         0           0
# 196    39  32.800         0         0           0
# 438    52  46.750         5         0           0
# 183    44  26.410         0         0           0
# 1298   33  27.455         2         1           0
# ...   ...     ...       ...       ...         ...
# 763    27  26.030         0         1           0
# 835    42  35.970         2         1           0
# 1216   40  25.080         0         1           0
# 559    19  35.530         0         1           0
# 684    33  18.500         1         0           0
#
# [936 rows x 5 columns]

# %%
# Model creation from Test data

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion':['squarded_error','absolute_error','poission''mae','friendman_mse'],'max_features':['auto','sqrt','log2'],'n_estimators':[10,100]}

grid= GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)

# Fitting the Model for grid seach                 
grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 100 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
# print best parameter after turning
# print(grid_best_params_)

# %%
re=grid.cv_results_
print("The r_score_value for best parameters:",format(grid.best_params_))
# Out:
# The r_score_value for best parameters: {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 100}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.012229      0.018380         0.000000        0.000000
# 1        0.004519      0.001002         0.000000        0.000000
# 2        0.008298      0.007904         0.000000        0.000000
# 3        0.004399      0.001854         0.000000        0.000000
# 4        0.006216      0.001973         0.000000        0.000000
# 5        0.004596      0.002244         0.000000        0.000000
# 6        0.008720      0.007369         0.000000        0.000000
# 7        0.005996      0.003517         0.000000        0.000000
# 8        0.229232      0.021663         0.010105        0.001621
# 9        2.012296      0.275059         0.036992        0.005528
# 10       0.211549      0.014270         0.013810        0.005800
# 11       1.879778      0.450861         0.026726        0.008558
# 12       0.002998      0.000632         0.000000        0.000000
# ...

# %%
age_input=float(input("Age:"))
bmi_input=float(input("bmi:"))
children_input=float(input("Children"))
sex_male_input=int(input("Sex_Male 0 or 1 :"))
smoker_input= int(input("Smoker Yes 0 to 1 :"))
# Out:
# Age: 30
# bmi: 41
# Children 2
# Sex_Male 0 or 1 : 1
# Smoker Yes 0 to 1 : 0

# %%
Future_prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_input]])
print("Future_Prediction-",format(Future_prediction))
# Out:
# Future_Prediction- [8759.85987925]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
 # save the Best Model

# %%
import pickle
filename="Finalized_model_Assignment_Regression.sav"

# %%
pickle.dump(regressor,open(filename,'wb'))

# %%
# Loaded the save Model

# %%
loaded_model=pickle.load(open("Finalized_model_Assignment_Regression.sav",'rb'))
result = loaded_model.predict([[1234,345,4565.789,555,1]])

# %%
result
